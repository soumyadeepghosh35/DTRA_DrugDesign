# %% [markdown]
# # This notebook is used to create bio-sythesis pipeline for top 20 recomended antiviral molecules using BioPKS

# %%
import sys
import os

# Completely suppress stderr output
sys.stderr = open(os.devnull, 'w')

# Now import everything
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from biopks_pipeline import biopks_pipeline
from DORA_XGB import DORA_XGB
import warnings
warnings.simplefilter('ignore')
from rdkit import Chem
import pygraphviz as pgv
import time

# %%
dataDir = '/mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/'
modelBuildingDataDir = os.path.join(dataDir, 'modelBuildingData/')
resultsDir = os.path.join(dataDir, 'Results/')
outputDir = os.path.join(resultsDir, 'BioPKS/virus/')

# %%
EnamineAntiviralsData_top20 = pd.read_csv(resultsDir + "virus/EnamineAntiviralsCompounds_allVirus.csv")
EnamineAntiviralsData_top20
# Out:
#     Rank                                           SMILES  \
# 0      1   COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# 1      2    COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# 2      3       COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# 3      4    COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# 4      5     COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# 5      6  CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC
# 6      7     CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C
# 7      8       CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O
# 8      9   CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C
# 9     10      COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2
# 10    11     CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C
# 11    12        COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3
# 12    13    COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC
# 13    14                  COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C
# 14    15               COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2
# 15    16            COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2
# 16    17       CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C
# 17    18         COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2
# 18    19      COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O
# 19    20            CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
#
#     pPotency_prediction      IC50 (M)
# 0                 7.089  8.149146e-08
# 1                 6.840  1.445621e-07
# 2                 6.794  1.608349e-07
# 3                 6.650  2.238847e-07
# 4                 6.643  2.273610e-07
# 5                 6.629  2.347164e-07
# 6                 6.600  2.510905e-07
# 7                 6.573  2.674945e-07
# 8                 6.547  2.837417e-07
# 9                 6.529  2.959537e-07
# 10                6.522  3.007342e-07
# 11                6.519  3.029676e-07
# 12                6.463  3.442486e-07
# 13                6.428  3.735013e-07
# 14                6.421  3.793359e-07
# 15                6.390  4.078300e-07
# 16                6.356  4.406266e-07
# 17                6.340  4.566632e-07
# 18                6.310  4.895722e-07
# 19                6.307  4.935332e-07

# %%
EnamineAntiviralsData_top20_SMILESonly = EnamineAntiviralsData_top20['SMILES']
EnamineAntiviralsData_top20_SMILESonly.to_csv(os.path.join(resultsDir + "virus/EnamineAntiviralsData_top20_SMILESonly.csv"), index=False)
EnamineAntiviralsData_top20_SMILESonly
# Out:
# 0      COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# 1       COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# 2          COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# 3       COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# 4        COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# 5     CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC
# 6        CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C
# 7          CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O
# 8      CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C
# 9         COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2
# 10       CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C
# 11          COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3
# 12      COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC
# 13                    COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C
# 14                 COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2
# 15              COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2
# 16         CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C
# 17           COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2
# 18        COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O
# 19              CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
# Name: SMILES, dtype: object

# %%
SMILES1 = EnamineAntiviralsData_top20_SMILESonly.iloc[0]
print(f"First SMILES: {SMILES1}")

# Validate and canonicalize using RDKit
def validate_and_canonicalize(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        canonical_smiles = Chem.MolToSmiles(mol)
        return canonical_smiles, True
    else:
        return None, False

# Process first SMILES
canon_first, valid_first = validate_and_canonicalize(SMILES1)
print(f"\nFirst SMILES valid: {valid_first}")
print(f"Canonical form: {canon_first}")
# Out:
# First SMILES: COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
#
# First SMILES valid: True
# Canonical form: COCCn1c(N(C)Cc2ccccc2)nc2c1c(=O)[nH]c(=O)n2C

# %% [markdown]
# Rule based PKS compatibility check using RDKit

# %%
def classifyPksFromSmiles(smiles):
    
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return False, "Invalid SMILES"

    # 1) Count carbonyls (C=O)
    carbonylPattern = Chem.MolFromSmarts("C=O")
    carbonylMatches = mol.GetSubstructMatches(carbonylPattern)
    numCarbonyls = len(carbonylMatches)

    # 2) Count oxygen atoms (rough proxy for oxygenation)
    numOxyAtoms = sum(1 for atom in mol.GetAtoms() if atom.GetSymbol() == "O")

    # 3) Look for a relatively long, non-ring, carbon chain (polyketide-like backbone)
    # Here: 10 sp3/sp2 carbons in a row outside rings as a simple heuristic
    longChainPattern = Chem.MolFromSmarts(
        "[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]"
    )
    longChainMatches = mol.GetSubstructMatches(longChainPattern)
    hasLongBackbone = len(longChainMatches) > 0

    # 4) Optional: look for ester / lactone motif (common in PKS products)
    esterPattern = Chem.MolFromSmarts("C(=O)O[C]")
    hasEster = mol.HasSubstructMatch(esterPattern)

    # Heuristic decision logic
    # You can tighten/loosen thresholds as needed
    if numCarbonyls >= 2 and numOxyAtoms >= 3 and (hasLongBackbone or hasEster):
        reason = (
            f"PKS-like: {numCarbonyls} carbonyls, {numOxyAtoms} O atoms, "
            f"{'long backbone' if hasLongBackbone else 'no long backbone'}, "
            f"{'ester present' if hasEster else 'no ester'}"
        )
        return True, reason

    reason = (
        f"Non-PKS-like: {numCarbonyls} carbonyls, {numOxyAtoms} O atoms, "
        f"{'long backbone' if hasLongBackbone else 'no long backbone'}, "
        f"{'ester present' if hasEster else 'no ester'}"
    )
    return False, reason


def addPksCompatibilityColumns(inputDf):
    """
    Takes a DataFrame with a 'SMILES' column and returns a copy with:
      - pksCompatible (bool)
      - pksReason (str)
    """
    DF = inputDf.copy()

    results = DF["SMILES"].apply(classifyPksFromSmiles)
    DF["pksCompatible"] = results.apply(lambda x: x[0])
    DF["pksReason"] = results.apply(lambda x: x[1])

    return DF


EnamineAntiviralsData_top20_PKSCompatibility = addPksCompatibilityColumns(
    EnamineAntiviralsData_top20
)
EnamineAntiviralsData_top20_PKSCompatibility
# Out:
#     Rank                                           SMILES  \
# 0      1   COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# 1      2    COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# 2      3       COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# 3      4    COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# 4      5     COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# 5      6  CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC
# 6      7     CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C
# 7      8       CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O
# 8      9   CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C
# 9     10      COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2
# 10    11     CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C
# 11    12        COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3
# 12    13    COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC
# 13    14                  COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C
# 14    15               COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2
# 15    16            COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2
# 16    17       CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C
# 17    18         COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2
# 18    19      COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O
# 19    20            CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
#
#     pPotency_prediction      IC50 (M)  pksCompatible  \
# 0                 7.089  8.149146e-08          False
# 1                 6.840  1.445621e-07          False
# 2                 6.794  1.608349e-07          False
# 3                 6.650  2.238847e-07          False
# 4                 6.643  2.273610e-07          False
# 5                 6.629  2.347164e-07          False
# 6                 6.600  2.510905e-07          False
# 7                 6.573  2.674945e-07          False
# 8                 6.547  2.837417e-07          False
# 9                 6.529  2.959537e-07          False
# 10                6.522  3.007342e-07          False
# 11                6.519  3.029676e-07          False
# 12                6.463  3.442486e-07          False
# 13                6.428  3.735013e-07          False
# 14                6.421  3.793359e-07          False
# 15                6.390  4.078300e-07          False
# 16                6.356  4.406266e-07          False
# 17                6.340  4.566632e-07          False
# 18                6.310  4.895722e-07          False
# 19                6.307  4.935332e-07          False
#
#                                             pksReason
# 0   Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 1   Non-PKS-like: 1 carbonyls, 4 O atoms, no long ...
# 2   Non-PKS-like: 1 carbonyls, 3 O atoms, no long ...
# 3   Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 4   Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 5   Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 6   Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 7   Non-PKS-like: 2 carbonyls, 2 O atoms, no long ...
# 8   Non-PKS-like: 2 carbonyls, 3 O atoms, no long ...
# 9   Non-PKS-like: 2 carbonyls, 4 O atoms, no long ...
# 10  Non-PKS-like: 2 carbonyls, 2 O atoms, no long ...
# 11  Non-PKS-like: 0 carbonyls, 3 O atoms, no long ...
# 12  Non-PKS-like: 0 carbonyls, 4 O atoms, no long ...
# 13  Non-PKS-like: 1 carbonyls, 2 O atoms, no long ...
# 14  Non-PKS-like: 2 carbonyls, 3 O atoms, no long ...
# 15  Non-PKS-like: 2 carbonyls, 4 O atoms, no long ...
# 16  Non-PKS-like: 2 carbonyls, 2 O atoms, no long ...
# 17  Non-PKS-like: 2 carbonyls, 4 O atoms, no long ...
# 18  Non-PKS-like: 1 carbonyls, 4 O atoms, no long ...
# 19  Non-PKS-like: 1 carbonyls, 1 O atoms, no long ...

# %% [markdown]
# Single-SMILES PKS Compatibility Checker

# %%
target_smiles = 'COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O'

# %%
def checkPksCompatibility(smiles):
    """
    Rule-based classifier for PKS compatibility.
    Returns a dictionary with pksCompatible (bool) and pksReason (text).
    """
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return {
            "pksCompatible": False,
            "pksReason": "Invalid SMILES",
        }

    # (1) Count carbonyls (C=O)
    carbonylPattern = Chem.MolFromSmarts("C=O")
    carbonylMatches = mol.GetSubstructMatches(carbonylPattern)
    numCarbonyls = len(carbonylMatches)

    # (2) Count oxygen atoms
    numOxyAtoms = sum(1 for atom in mol.GetAtoms() if atom.GetSymbol() == "O")

    # (3) Detect long, non-ring carbon chain (simple polyketide backbone signal)
    longChainPattern = Chem.MolFromSmarts(
        "[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]-[C;!R]"
    )
    longChainMatches = mol.GetSubstructMatches(longChainPattern)
    hasLongBackbone = len(longChainMatches) > 0

    # (4) Detect ester / lactone motif (common in polyketides)
    esterPattern = Chem.MolFromSmarts("C(=O)O[C]")
    hasEster = mol.HasSubstructMatch(esterPattern)

    # Heuristic decision logic
    if numCarbonyls >= 2 and numOxyAtoms >= 3 and (hasLongBackbone or hasEster):
        return {
            "pksCompatible": True,
            "pksReason": (
                f"PKS-like structure: {numCarbonyls} carbonyls, "
                f"{numOxyAtoms} oxygen atoms, "
                f"{'long backbone detected' if hasLongBackbone else 'no long backbone'}, "
                f"{'ester present' if hasEster else 'no ester'}."
            ),
        }

    return {
        "pksCompatible": False,
        "pksReason": (
            f"Not PKS-like: {numCarbonyls} carbonyls, "
            f"{numOxyAtoms} oxygen atoms, "
            f"{'long backbone detected' if hasLongBackbone else 'no long backbone'}, "
            f"{'ester present' if hasEster else 'no ester'}."
        ),
    }



result = checkPksCompatibility(target_smiles)

print("SMILES:", target_smiles)
print("PKS Compatible:", result["pksCompatible"])
print("Reason:", result["pksReason"])
# Out:
# SMILES: COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# PKS Compatible: False
# Reason: Not PKS-like: 1 carbonyls, 4 oxygen atoms, no long backbone, no ester.

# %% [markdown]
# Define parameters for BioPKS

# %%
pathway_sequence = ['pks','bio']  # choose between ['pks'] or ['pks','bio']
target_name = 'gluconic_lactone'
pks_release_mechanism = 'thiolysis' # choose from 'cyclization' or 'thiolysis'

# %%
from rdkit import Chem
Chem.MolFromSmiles(target_smiles)

# %% [markdown]
# Define configuration file path for BioPKS

# %%
config_filepath = os.path.join('/mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/BioPKS_config_file.json')

# %% [markdown]
# we initialize DORA-XGB, a supervised learning classifier that can help predict the feasibility of reactions catalyzed by regular, monofunctional enzymes in Biology.

# %%
post_pks_rxn_model = DORA_XGB.feasibility_classifier(cofactor_positioning = 'add_concat',
                                                     model_type = "spare")

# %% [markdown]
# initialize an object of the biopks_pipeline class

# %%
biopks_pipeline_object = biopks_pipeline.biopks_pipeline(
                                             pathway_sequence = pathway_sequence,
                                             target_smiles = target_smiles,
                                             target_name = target_name,
                                             feasibility_classifier = post_pks_rxn_model,
                                             pks_release_mechanism = pks_release_mechanism,
                                             config_filepath = config_filepath
                                             )
# Out:
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases

# %% [markdown]
# begin a combined PKS and post-PKS synthesis with BioPKS Pipeline

# %%
### ----- Start synthesis -----
if __name__ == "__main__":
    start_time = time.time()
    biopks_pipeline_object.run_combined_synthesis(max_designs = 4)
    biopks_pipeline_object.save_results_logs()

    print(f"Time: {time.time() - start_time: .2f} s")
# Out:
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.15384615384615385
# computing module 2
#    testing 600 designs
#    best score is 0.14285714285714285
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: CC=C(OC)C(=O)O
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is CC=C(OC)C(=O)O.
#
# Moving onto non-PKS modifications...
# Job name: gluconic_lactone_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:33:32.368460
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 127
# Number of reactions: 98
# Time used for network generation: 0.44 minutes
#
# Job name: gluconic_lactone_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:34:01.398673
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 98
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 97
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:34:01.445813
# Pathway finder started, total number of reactions in network 97
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:34:01.462275
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:34:01.462625
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: gluconic_lactone_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:34:02.275808
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 146
# Number of reactions: 118
# Time used for network generation: 0.48 minutes
#
# Job name: gluconic_lactone_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:34:33.699287
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 118
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 116
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:34:33.727481
# Pathway finder started, total number of reactions in network 116
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:34:33.742286
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:34:33.742633
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: gluconic_lactone_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:34:34.535043
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 141
# Number of reactions: 109
# Time used for network generation: 0.46 minutes
#
# Job name: gluconic_lactone_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:35:04.486668
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 109
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 107
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:35:04.514584
# Pathway finder started, total number of reactions in network 107
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:35:04.528911
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:35:04.529260
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: gluconic_lactone_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:35:05.276075
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 144
# Number of reactions: 113
# Time used for network generation: 0.48 minutes
#
# Job name: gluconic_lactone_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:35:36.408422
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 113
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 112
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:35:36.433436
# Pathway finder started, total number of reactions in network 112
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:35:36.447883
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:35:36.448232
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: gluconic_lactone_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:35:37.268395
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.60 minutes
#
# Job name: gluconic_lactone_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:36:16.078823
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:36:16.110716
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:36:16.131466
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:36:16.131821
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: gluconic_lactone_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 10:36:16.919445
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.61 minutes
#
# Job name: gluconic_lactone_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 10:36:55.893852
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: gluconic_lactone_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 10:36:55.931988
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: gluconic_lactone_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 10:36:55.953301
# Pathway file not found, exiting pathway ranking
#
# Job name: gluconic_lactone_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 10:36:55.953656
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
# Time:  204.73 s

# %% [markdown]
# ### Run BioPKS pipeline for all molecules in the dataframe

# %%
import time
from tqdm import tqdm  # for progress bar (install with: pip install tqdm)

# Optional: Filter to only PKS-compatible molecules first
# df_to_process = EnamineAntiviralsData_top20_PKSCompatibility[
#     EnamineAntiviralsData_top20_PKSCompatibility['pksCompatible'] == True
# ].copy()

# Or process all molecules
df_to_process = EnamineAntiviralsData_top20.copy()

# Store results
results_summary = []

# Parameters (same for all runs)
pathway_sequence = ['pks','bio']
pks_release_mechanism = 'thiolysis'
config_filepath = os.path.join(
    '/mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/BioPKS_config_file.json'
)

# Initialize the post-PKS reaction model once (reuse for all)
post_pks_rxn_model = DORA_XGB.feasibility_classifier(
    cofactor_positioning='add_concat',
    model_type="spare"
)

# Loop through all SMILES
for idx, row in tqdm(df_to_process.iterrows(), total=len(df_to_process), desc="Processing molecules"):
    
    target_smiles = row['SMILES']
    # Create a unique target name (you can customize this)
    target_name = f"molecule_{idx+1}"
    
    print(f"\n{'-'*60}")
    print(f"Processing {idx+1}/{len(df_to_process)}: {target_name}")
    print(f"SMILES: {target_smiles}")
    print(f"{'-'*60}")
    
    try:
        start_time = time.time()
        
        # Initialize BioPKS pipeline for this molecule
        biopks_pipeline_object = biopks_pipeline.biopks_pipeline(
            pathway_sequence=pathway_sequence,
            target_smiles=target_smiles,
            target_name=target_name,
            feasibility_classifier=post_pks_rxn_model,
            pks_release_mechanism=pks_release_mechanism,
            config_filepath=config_filepath
        )
        
        # Run synthesis
        biopks_pipeline_object.run_combined_synthesis(max_designs=4)
        
        # Save results
        biopks_pipeline_object.save_results_logs()
        
        elapsed_time = time.time() - start_time
        
        # Record success
        results_summary.append({
            'index': idx,
            'SMILES': target_smiles,
            'target_name': target_name,
            'status': 'Success',
            'time_seconds': elapsed_time,
            'error': None
        })
        
        print(f" Completed in {elapsed_time:.2f} seconds")
        
    except Exception as e:
        # Record failure
        error_msg = str(e)
        results_summary.append({
            'index': idx,
            'SMILES': target_smiles,
            'target_name': target_name,
            'status': 'Failed',
            'time_seconds': None,
            'error': error_msg
        })
        
        print(f" Failed with error: {error_msg}")
        continue  # Continue to next molecule

# Create summary dataframe
results_df = pd.DataFrame(results_summary)

# Save summary
summary_path = os.path.join(outputDir, 'BioPKS_batch_processing_summary.csv')
results_df.to_csv(summary_path, index=False)

print(f"\n{'-'*60}")
print("BATCH PROCESSING COMPLETE")
print(f"{'-'*60}")
print(f"Total molecules: {len(df_to_process)}")
print(f"Successful: {(results_df['status'] == 'Success').sum()}")
print(f"Failed: {(results_df['status'] == 'Failed').sum()}")
print(f"Summary saved to: {summary_path}")
print(f"{'='*60}")

# Display summary
results_df
# Out:
# ------------------------------------------------------------
# Processing 1/20: molecule_1
# SMILES: COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.14814814814814814
# computing module 2
#    testing 600 designs
#    best score is 0.13793103448275862
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: CC=C(OC)C(=O)O
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is CC=C(OC)C(=O)O.
#
# Moving onto non-PKS modifications...
# Job name: molecule_1_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:22:23.533467
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 127
# Number of reactions: 98
# Time used for network generation: 0.43 minutes
#
# Job name: molecule_1_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:22:51.913688
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 98
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 97
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:22:51.944009
# Pathway finder started, total number of reactions in network 97
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:22:51.957481
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:22:51.958161
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: molecule_1_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:22:52.746426
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 146
# Number of reactions: 118
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_1_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:23:24.197946
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 118
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 116
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:23:24.229989
# Pathway finder started, total number of reactions in network 116
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:23:24.244847
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:23:24.245555
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_1_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:23:25.043583
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 141
# Number of reactions: 109
# Time used for network generation: 0.46 minutes
#
# Job name: molecule_1_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:23:55.046423
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 109
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 107
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:23:55.094764
# Pathway finder started, total number of reactions in network 107
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:23:55.110180
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:23:55.111084
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_1_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:23:55.932131
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 144
# Number of reactions: 113
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_1_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:24:26.957952
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 113
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 112
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:24:26.993180
# Pathway finder started, total number of reactions in network 112
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:24:27.007342
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:24:27.007972
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_1_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:24:27.840836
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.61 minutes
#
# Job name: molecule_1_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:25:06.754538
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:25:06.782137
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:25:06.802928
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:25:06.803849
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_1_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:25:07.738093
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.61 minutes
#
# Job name: molecule_1_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:25:46.739422
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_1_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:25:46.789849
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_1_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:25:46.812235
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_1_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:25:46.812987
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 204.58 seconds
#
# ------------------------------------------------------------
# Processing 2/20: molecule_2
# SMILES: COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.15384615384615385
# computing module 2
#    testing 600 designs
#    best score is 0.14285714285714285
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: CC=C(OC)C(=O)O
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is CC=C(OC)C(=O)O.
#
# Moving onto non-PKS modifications...
# Job name: molecule_2_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:25:47.932784
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 127
# Number of reactions: 98
# Time used for network generation: 0.43 minutes
#
# Job name: molecule_2_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:26:16.344659
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 98
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 97
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:26:16.372019
# Pathway finder started, total number of reactions in network 97
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:26:16.385173
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:26:16.385796
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: molecule_2_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:26:17.200347
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 146
# Number of reactions: 118
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_2_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:26:48.717947
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 118
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 116
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:26:48.766460
# Pathway finder started, total number of reactions in network 116
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:26:48.781922
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:26:48.782506
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_2_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:26:49.583404
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 141
# Number of reactions: 109
# Time used for network generation: 0.46 minutes
#
# Job name: molecule_2_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:27:19.425521
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 109
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 107
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:27:19.456137
# Pathway finder started, total number of reactions in network 107
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:27:19.470383
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:27:19.471130
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_2_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:27:20.223954
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 144
# Number of reactions: 113
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_2_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:27:51.347244
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 113
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 112
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:27:51.395146
# Pathway finder started, total number of reactions in network 112
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:27:51.411068
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:27:51.411843
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_2_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:27:52.156078
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.60 minutes
#
# Job name: molecule_2_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:28:30.914375
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:28:30.947514
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:28:30.968239
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:28:30.969002
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_2_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:28:31.754421
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.61 minutes
#
# Job name: molecule_2_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:29:10.675344
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_2_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:29:10.723991
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_2_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:29:10.745256
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_2_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:29:10.746130
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 203.78 seconds
#
# ------------------------------------------------------------
# Processing 3/20: molecule_3
# SMILES: COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.30434782608695654
# computing module 2
#    testing 600 designs
#    best score is 0.375
# computing module 3
#    testing 600 designs
#    best score is 0.34615384615384615
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Allylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False'], ["AT{'substrate': 'Methylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: C=CC[C@H](C=C(C)C(=O)O)CC
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Allylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False'], ["AT{'substrate': 'Methylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is C=CC[C@H](C=C(C)C(=O)O)CC.
#
# Moving onto non-PKS modifications...
# Job name: molecule_3_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:29:12.126013
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 301
# Number of reactions: 286
# Time used for network generation: 0.88 minutes
#
# Job name: molecule_3_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:30:07.256424
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 286
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 284
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:30:07.287280
# Pathway finder started, total number of reactions in network 284
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:30:07.313515
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:30:07.314224
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: molecule_3_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:30:08.197370
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 331
# Number of reactions: 320
# Time used for network generation: 1.02 minutes
#
# Job name: molecule_3_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:31:11.938189
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 320
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 318
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:31:11.992304
# Pathway finder started, total number of reactions in network 318
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:31:12.026557
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:31:12.027369
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_3_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:31:13.013448
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 334
# Number of reactions: 328
# Time used for network generation: 0.99 minutes
#
# Job name: molecule_3_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:32:14.686113
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 328
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 326
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:32:14.738694
# Pathway finder started, total number of reactions in network 326
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:32:14.770191
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:32:14.770926
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_3_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:32:15.744635
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 331
# Number of reactions: 320
# Time used for network generation: 1.02 minutes
#
# Job name: molecule_3_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:33:19.469597
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 320
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 318
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:33:19.506734
# Pathway finder started, total number of reactions in network 318
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:33:19.540825
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:33:19.541629
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_3_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:33:20.526736
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 353
# Number of reactions: 340
# Time used for network generation: 1.03 minutes
#
# Job name: molecule_3_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:34:24.603368
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 340
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 338
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:34:24.656658
# Pathway finder started, total number of reactions in network 338
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:34:24.688065
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:34:24.688891
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_3_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:34:25.653025
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 343
# Number of reactions: 326
# Time used for network generation: 1.00 minutes
#
# Job name: molecule_3_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:35:28.327991
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 326
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 324
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_3_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:35:28.359562
# Pathway finder started, total number of reactions in network 324
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_3_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:35:28.391228
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_3_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:35:28.391945
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 377.82 seconds
#
# ------------------------------------------------------------
# Processing 4/20: molecule_4
# SMILES: COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.14814814814814814
# computing module 2
#    testing 600 designs
#    best score is 0.13793103448275862
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: CC=C(OC)C(=O)O
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Methoxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is CC=C(OC)C(=O)O.
#
# Moving onto non-PKS modifications...
# Job name: molecule_4_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:35:29.532855
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 127
# Number of reactions: 98
# Time used for network generation: 0.43 minutes
#
# Job name: molecule_4_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:35:57.913632
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 98
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 97
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:35:57.962980
# Pathway finder started, total number of reactions in network 97
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:35:57.977849
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:35:57.978774
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: molecule_4_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:35:58.841939
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 146
# Number of reactions: 118
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_4_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:36:30.457537
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 118
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 116
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:36:30.496151
# Pathway finder started, total number of reactions in network 116
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:36:30.511330
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:36:30.512133
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_4_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:36:31.391758
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 141
# Number of reactions: 109
# Time used for network generation: 0.46 minutes
#
# Job name: molecule_4_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:37:01.442671
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 109
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 107
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:37:01.491539
# Pathway finder started, total number of reactions in network 107
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:37:01.507286
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:37:01.508123
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_4_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:37:02.296901
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 144
# Number of reactions: 113
# Time used for network generation: 0.48 minutes
#
# Job name: molecule_4_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:37:33.356931
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 113
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 112
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:37:33.401488
# Pathway finder started, total number of reactions in network 112
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:37:33.417589
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:37:33.418416
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_4_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:37:34.211252
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.61 minutes
#
# Job name: molecule_4_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:38:13.252619
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:38:13.284908
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:38:13.305727
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:38:13.306475
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_4_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 11:38:14.166553
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 176
# Number of reactions: 153
# Time used for network generation: 0.60 minutes
#
# Job name: molecule_4_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 11:38:52.959980
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 153
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 152
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_4_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 11:38:53.001960
# Pathway finder started, total number of reactions in network 152
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_4_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 11:38:53.023780
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_4_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 11:38:53.024607
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 204.55 seconds
#
# ------------------------------------------------------------
# Processing 5/20: molecule_5
# SMILES: COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.16666666666666666
# computing module 2
#    testing 600 designs
#    best score is 0.15384615384615385
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Hydroxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False']]
#
# Closest final product is: CC[C@H](O)C(=O)O
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Hydroxymalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False']] is CC[C@H](O)C(=O)O.
#
# Moving onto non-PKS modifications...
# Job name: molecule_5_PKS0_BIO1
# Job type: enzymatic network expansion forward
# ...
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:42:33.277568
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 118
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 116
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_19_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:42:33.327585
# Pathway finder started, total number of reactions in network 116
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_19_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:42:33.343352
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_19_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:42:33.344006
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 214.97 seconds
#
# ------------------------------------------------------------
# Processing 20/20: molecule_20
# SMILES: CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
# ------------------------------------------------------------
#
# Extender units successfully chosen for polyketide synthases
#
# Starter units successfully chosen for polyketide synthases
#
# Starting PKS synthesis with RetroTide
# ---------------------------------------------
# computing module 1
#    testing 120 designs
#    best score is 0.35
# computing module 2
#    testing 600 designs
#    best score is 0.42857142857142855
# computing module 3
#    testing 600 designs
#    best score is 0.391304347826087
#
# Best PKS design: [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Allylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False'], ["AT{'substrate': 'Methylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']]
#
# Closest final product is: C=CC[C@H](C=C(C)C(=O)O)CC
#
# Finished PKS synthesis: closest product to the target using the top PKS design of [["AT{'substrate': 'Malonyl-CoA'}", 'loading: True'], ["AT{'substrate': 'Allylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'ER{}', 'loading: False'], ["AT{'substrate': 'Methylmalonyl-CoA'}", "KR{'type': 'B1'}", 'DH{}', 'loading: False']] is C=CC[C@H](C=C(C)C(=O)O)CC.
#
# Moving onto non-PKS modifications...
# Job name: molecule_20_PKS0_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:42:34.597182
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 301
# Number of reactions: 286
# Time used for network generation: 0.87 minutes
#
# Job name: molecule_20_PKS0_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:43:29.604648
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 286
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 284
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS0_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:43:29.651732
# Pathway finder started, total number of reactions in network 284
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS0_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:43:29.678335
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS0_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:43:29.679161
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways to target are found using non-PKS enzymes for 1 step/s and the top PKS module design
#
# Attempting non-PKS pathways for 1 step/s on PKS product from the next 4 best PKS designs that produce unique PKS products.
# Job name: molecule_20_PKS1_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:43:30.579109
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 331
# Number of reactions: 320
# Time used for network generation: 1.02 minutes
#
# Job name: molecule_20_PKS1_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:44:34.524439
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 320
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 318
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS1_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:44:34.575660
# Pathway finder started, total number of reactions in network 318
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS1_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:44:34.609632
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS1_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:44:34.610331
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #1 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_20_PKS2_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:44:35.608462
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 334
# Number of reactions: 328
# Time used for network generation: 0.98 minutes
#
# Job name: molecule_20_PKS2_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:45:37.173547
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 328
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 326
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS2_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:45:37.227520
# Pathway finder started, total number of reactions in network 326
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS2_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:45:37.259103
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS2_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:45:37.259880
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #2 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_20_PKS3_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:45:38.127835
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 331
# Number of reactions: 320
# Time used for network generation: 1.02 minutes
#
# Job name: molecule_20_PKS3_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:46:42.091968
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 320
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 318
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS3_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:46:42.147666
# Pathway finder started, total number of reactions in network 318
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS3_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:46:42.181799
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS3_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:46:42.182647
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #3 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_20_PKS4_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:46:43.153617
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 353
# Number of reactions: 340
# Time used for network generation: 1.02 minutes
#
# Job name: molecule_20_PKS4_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:47:47.245550
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 340
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 338
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS4_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:47:47.289905
# Pathway finder started, total number of reactions in network 338
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS4_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:47:47.320833
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS4_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:47:47.321532
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #4 out of all RetroTide designs. Moving onto the next unique PKS design
# Job name: molecule_20_PKS5_BIO1
# Job type: enzymatic network expansion forward
# Job started on: 2025-12-11 12:47:48.274724
# Number of generations: 1
# Number of operators loaded: 3571
# Number of molecules before expantion (including cofactors): 42
# Number of molecules after expantion (including cofactors): 343
# Number of reactions: 326
# Time used for network generation: 1.00 minutes
#
# Job name: molecule_20_PKS5_BIO1
# Job type: post-processing pretreat networks
# Job started on: 2025-12-11 12:48:50.830531
# Loading networks, it may take a while if loading large networks from file
# Loading network 1 from memory
# Number of reations in network 1: 326
# Networks loaded, now generating reaction strings
# Reaction strings generation finished
# Removing unconnected reactions
# Unconnected reactions removed
# Total number of reactions after pretreatment: 324
# Time used for network pretreatment: 0.00 minutes
#
# Job name: molecule_20_PKS5_BIO1
# Job type: pathway search
# Job started on: 2025-12-11 12:48:50.868799
# Pathway finder started, total number of reactions in network 324
# Searching for pathways.
# If it is taking too long, try adjusting pruning parameters
# No pathway found! Try adjusting pruning parameters.
# Pathway search finished, removing loops if there's any.
# Time used for pathway search: 0.00 minutes
#
# Job name: molecule_20_PKS5_BIO1
# Job type: pathway ranking
# Job started on: 2025-12-11 12:48:50.900519
# Pathway file not found, exiting pathway ranking
#
# Job name: molecule_20_PKS5_BIO1
# Job type: pathway visualization
# Job started on: 2025-12-11 12:48:50.901312
# Ranked pathway file not found, exiting pathway visualization
#
#
# No pathways found with non-PKS enzymes in 1 step/s using unique PKS design #5 out of all RetroTide designs. Moving onto the next unique PKS design
#  Completed in 377.74 seconds
#
# ------------------------------------------------------------
# BATCH PROCESSING COMPLETE
# ------------------------------------------------------------
# Total molecules: 20
# Successful: 20
# Failed: 0
# Summary saved to: /mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/BioPKS_batch_processing_summary.csv
# ============================================================
#     index                                           SMILES  target_name  \
# 0       0   COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3   molecule_1
# 1       1    COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O   molecule_2
# 2       2       COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C   molecule_3
# 3       3    COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3   molecule_4
# 4       4     COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32   molecule_5
# 5       5  CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC   molecule_6
# 6       6     CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C   molecule_7
# 7       7       CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O   molecule_8
# 8       8   CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C   molecule_9
# 9       9      COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2  molecule_10
# 10     10     CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C  molecule_11
# 11     11        COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3  molecule_12
# 12     12    COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC  molecule_13
# 13     13                  COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C  molecule_14
# 14     14               COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2  molecule_15
# 15     15            COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2  molecule_16
# 16     16       CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C  molecule_17
# 17     17         COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2  molecule_18
# 18     18      COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O  molecule_19
# 19     19            CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C  molecule_20
#
#      status  time_seconds error
# 0   Success    204.579985  None
# 1   Success    203.776587  None
# 2   Success    377.824651  None
# 3   Success    204.551454  None
# 4   Success    209.620897  None
# 5   Success    204.257101  None
# 6   Success    204.877500  None
# 7   Success    325.863275  None
# 8   Success    254.017915  None
# 9   Success    220.850075  None
# 10  Success    218.328178  None
# 11  Success    204.109243  None
# 12  Success    204.029832  None
# 13  Success    271.960820  None
# 14  Success    191.095545  None
# 15  Success    215.105995  None
# 16  Success    377.515514  None
# 17  Success    503.554043  None
# 18  Success    214.971282  None
# 19  Success    377.738765  None

# %% [markdown]
# Retrosynthesis Tools: IBM RXN for Chemistry

# %%
# Configuration Parameters
apiKey = 'apk-7a2cc4604d776559c56bf39435eb59e2ffcd2399ede3895eb750d565649d7756'

# %%
# IBM RXN for Chemistry - Batch Retrosynthesis Pipeline
# Process all molecules in EnamineAntiviralsData_top20 dataframe

from rxn4chemistry import RXN4ChemistryWrapper
import pandas as pd
import numpy as np
import time
import json
import os
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

try:
    import matplotlib.pyplot as plt
    hasMatplotlib = True
except ImportError:
    hasMatplotlib = False

# ------------------------------------------------------------------
# Configuration Parameters
# ------------------------------------------------------------------
maxRoutesPerMolecule = 5
maxRetrosynthesisSteps = 6
nBeams = 10
fapThreshold = 0.6
aiModel = '12class-tokens-2021-05-14'  # use default or other model as needed

# ------------------------------------------------------------------
# Initialize RXN API Connection
# ------------------------------------------------------------------
print("Initializing IBM RXN for Chemistry API...")

try:
    rxnWrapper = RXN4ChemistryWrapper(api_key=apiKey)
    # For cloud usage this is usually not needed, but harmless:
    rxnWrapper.set_base_url('https://rxn.res.ibm.com')

    projects_response = rxnWrapper.list_all_projects()
    existingProjects = projects_response.get('projects', []) if isinstance(projects_response, dict) else []
    print("API connection successful")
    print(f"Found {len(existingProjects)} existing projects")

except Exception as e:
    print(f"API connection failed: {e}")
    print("\nPlease check:")
    print("1. API key is correctly set")
    print("2. Internet connection is active")
    print("3. Get API key from: https://rxn.res.ibm.com/rxn/user/profile")
    raise

# ------------------------------------------------------------------
# Setup Project — follow docs exactly
# ------------------------------------------------------------------
projectName = 'Enamine_Antivirals_Retrosynthesis'

print(f"\nCreating / selecting project: {projectName}")

# As in docs:
#   rxn.create_project("rxn4chemistry_tour")
#   rxn.set_project(rxn.project_id)
try:
    rxnWrapper.create_project(projectName)
    rxnWrapper.set_project(rxnWrapper.project_id)
    projectId = rxnWrapper.project_id
    print(f"Using project '{projectName}' with ID: {projectId}")
except Exception as e:
    # If project already exists or something odd happens, try to find it
    print(f"create_project raised: {e}")
    print("Trying to find an existing project with the same name...")

    projects = rxnWrapper.list_all_projects()
    projectList = projects.get('projects', []) if isinstance(projects, dict) else []

    projectId = None
    for proj in projectList:
        if proj.get('name') == projectName:
            projectId = proj.get('id') or proj.get('project_id')
            break

    if projectId is None:
        raise RuntimeError(
            f"Could not obtain a valid project id for project '{projectName}'. "
            f"Please create a project in the RXN GUI or check your subscription."
        )

    rxnWrapper.set_project(projectId)
    print(f"Using existing project '{projectName}' with ID: {projectId}")

print("Project ID set successfully\n")

# ------------------------------------------------------------------
# Function to process a single molecule
# ------------------------------------------------------------------
def processSingleMolecule(
    smiles,
    moleculeId,
    apiWrapper,
    maxResults=5,
    maxSteps=6,
    nBeams=10,
    fap=0.6,
    aiModel='12class-tokens-2021-05-14'
):
    """
    Process a single molecule through IBM RXN retrosynthesis.
    Returns: (resultDict, errorMessage)
    """
    try:
        # As in docs:
        # predict_automatic_retrosynthesis_response = rxn.predict_automatic_retrosynthesis(product=smiles)
        rawResponse = apiWrapper.predict_automatic_retrosynthesis(
            product=smiles,
            availability_pricing_threshold=0,
            available_smiles=None,
            exclude_smiles=None,
            exclude_substructures=None,
            exclude_target_molecule=False,
            fap=fap,
            max_steps=maxSteps,
            nbeams=nBeams,
            pruning_steps=2,
            ai_model=aiModel
        )

        if not isinstance(rawResponse, dict):
            return None, f"Unexpected response type for {moleculeId}: {type(rawResponse)}"

        # Doc pattern: predict_automatic_retrosynthesis_results = rxn.get_predict_automatic_retrosynthesis_results(
        #     predict_automatic_retrosynthesis_response['prediction_id']
        # )
        if 'prediction_id' not in rawResponse:
            msg = rawResponse.get('message') or rawResponse.get('status') or "No 'prediction_id' in response."
            return None, (
                f"IBM RXN did not return a prediction_id for {moleculeId}. "
                f"Message: {msg}. Raw response: {rawResponse}"
            )

        predictionId = rawResponse['prediction_id']

        # Poll for results until status == 'SUCCESS', following docs
        retries = 0
        maxRetries = 60   # 60 * 5s = 5 minutes total

        while retries < maxRetries:
            results = apiWrapper.get_predict_automatic_retrosynthesis_results(
                prediction_id=predictionId
            )

            if not isinstance(results, dict):
                return None, f"Unexpected result type for {moleculeId}: {type(results)}"

            status = results.get('status', 'UNKNOWN')

            if status == 'SUCCESS':
                routes = results.get('retrosynthetic_paths', []) or []

                routeData = []
                for route in routes[:maxResults]:
                    sequenceIds = route.get('sequenceId') or []
                    if sequenceIds is None:
                        sequenceIds = []
                    routeInfo = {
                        'confidence': route.get('confidence'),
                        'numSteps': len(sequenceIds),
                        'sequenceIds': sequenceIds,
                        'fullRoute': route
                    }
                    routeData.append(routeInfo)

                return {
                    'predictionId': predictionId,
                    'numRoutes': len(routes),
                    'routes': routeData,
                    'fullResponse': results
                }, None

            elif status in ['FAILED', 'ERROR']:
                errorMsg = results.get('message') or f"Prediction failed with status: {status}"
                return None, errorMsg

            # Still pending
            time.sleep(5)
            retries += 1

        return None, f"Timeout waiting for results after {maxRetries * 5} seconds"

    except Exception as e:
        return None, f"Exception during retrosynthesis for {moleculeId}: {e}"

# ------------------------------------------------------------------
# Function to process all molecules in batch
# ------------------------------------------------------------------
def processBatchRetrosynthesis(
    dataframe,
    apiWrapper,
    maxResults=5,
    maxSteps=6,
    nBeams=10,
    fap=0.6,
    aiModel='12class-tokens-2021-05-14'
):
    """
    Process all molecules in dataframe through IBM RXN.
    Returns: (summaryDataframe, detailedResultsDict)
    """

    resultsSummary = []
    detailedResults = {}

    print(f"\nProcessing {len(dataframe)} molecules through IBM RXN\n")

    for idx, row in tqdm(dataframe.iterrows(), total=len(dataframe), desc="Processing"):

        targetSmiles = row['SMILES']
        moleculeId = f"molecule_{idx}"

        print(f"\n[{idx+1}/{len(dataframe)}] {moleculeId}")
        print(f"SMILES: {targetSmiles}")

        startTime = time.time()

        result, error = processSingleMolecule(
            smiles=targetSmiles,
            moleculeId=moleculeId,
            apiWrapper=apiWrapper,
            maxResults=maxResults,
            maxSteps=maxSteps,
            nBeams=nBeams,
            fap=fap,
            aiModel=aiModel
        )

        elapsedTime = time.time() - startTime

        if error:
            print(f"Failed: {error}")
            resultsSummary.append({
                'index': idx,
                'moleculeId': moleculeId,
                'smiles': targetSmiles,
                'status': 'Failed',
                'numRoutes': 0,
                'topRouteConfidence': None,
                'topRouteSteps': None,
                'predictionId': None,
                'timeSeconds': elapsedTime,
                'error': error
            })

        elif result['numRoutes'] == 0:
            print("No routes found")
            resultsSummary.append({
                'index': idx,
                'moleculeId': moleculeId,
                'smiles': targetSmiles,
                'status': 'No routes found',
                'numRoutes': 0,
                'topRouteConfidence': None,
                'topRouteSteps': None,
                'predictionId': result['predictionId'],
                'timeSeconds': elapsedTime,
                'error': None
            })

        else:
            topRoute = result['routes'][0]
            print(f"Success: {result['numRoutes']} routes found")
            if topRoute['confidence'] is not None:
                print(f"Top route: {topRoute['numSteps']} steps, confidence: {topRoute['confidence']:.3f}")
            else:
                print(f"Top route: {topRoute['numSteps']} steps, confidence: None")

            resultsSummary.append({
                'index': idx,
                'moleculeId': moleculeId,
                'smiles': targetSmiles,
                'status': 'Success',
                'numRoutes': result['numRoutes'],
                'topRouteConfidence': topRoute['confidence'],
                'topRouteSteps': topRoute['numSteps'],
                'predictionId': result['predictionId'],
                'timeSeconds': elapsedTime,
                'error': None
            })

            detailedResults[moleculeId] = {
                'smiles': targetSmiles,
                'predictionId': result['predictionId'],
                'numRoutes': result['numRoutes'],
                'routes': result['routes'],
                'processingTime': elapsedTime
            }

    return pd.DataFrame(resultsSummary), detailedResults

# ------------------------------------------------------------------
# Run Batch Processing
# ------------------------------------------------------------------
print("\nStarting Batch Retrosynthesis Analysis")
print(f"Input molecules: {len(EnamineAntiviralsData_top20)}")
print(f"Max routes per molecule: {maxRoutesPerMolecule}")
print(f"Max synthesis steps: {maxRetrosynthesisSteps}")
print(f"Project ID: {rxnWrapper.project_id}\n")

batchStartTime = time.time()

summaryDf, detailedResults = processBatchRetrosynthesis(
    dataframe=EnamineAntiviralsData_top20,
    apiWrapper=rxnWrapper,
    maxResults=maxRoutesPerMolecule,
    maxSteps=maxRetrosynthesisSteps,
    nBeams=nBeams,
    fap=fapThreshold,
    aiModel=aiModel
)

totalTime = time.time() - batchStartTime

# ------------------------------------------------------------------
# Save Results
# ------------------------------------------------------------------
print("\n\nSaving Results")

rxnOutputDir = os.path.join(outputDir, 'IBM_RXN_results')
os.makedirs(rxnOutputDir, exist_ok=True)

summaryPath = os.path.join(rxnOutputDir, 'retrosynthesis_summary.csv')
summaryDf.to_csv(summaryPath, index=False)
print(f"Summary saved: {summaryPath}")

detailedPath = os.path.join(rxnOutputDir, 'detailed_results.json')
with open(detailedPath, 'w') as f:
    json.dump(detailedResults, f, indent=2)
print(f"Detailed results saved: {detailedPath}")

routesDir = os.path.join(rxnOutputDir, 'individual_routes')
os.makedirs(routesDir, exist_ok=True)

for molId, data in detailedResults.items():
    molDir = os.path.join(routesDir, molId)
    os.makedirs(molDir, exist_ok=True)

    molData = {
        'smiles': data['smiles'],
        'numRoutes': data['numRoutes'],
        'processingTime': data['processingTime'],
        'routes': data['routes']
    }

    with open(os.path.join(molDir, 'routes.json'), 'w') as f:
        json.dump(molData, f, indent=2)

print(f"Individual routes saved: {routesDir}")

# ------------------------------------------------------------------
# Generate Statistics
# ------------------------------------------------------------------
print("\n\nAnalysis Summary")

totalMolecules = len(summaryDf)
successful = (summaryDf['status'] == 'Success').sum()
noRoutes = (summaryDf['status'] == 'No routes found').sum()
failed = (summaryDf['status'] == 'Failed').sum()

print(f"Total molecules processed: {totalMolecules}")
print(f"Successful: {successful} ({100*successful/totalMolecules:.1f}%)")
print(f"No routes found: {noRoutes} ({100*noRoutes/totalMolecules:.1f}%)")
print(f"Failed: {failed} ({100*failed/totalMolecules:.1f}%)")
print(f"\nTotal processing time: {totalTime/60:.1f} minutes")
print(f"Average time per molecule: {totalTime/totalMolecules:.1f} seconds")

if successful > 0:
    successDf = summaryDf[summaryDf['status'] == 'Success']

    print(f"\nRoute Statistics (successful molecules):")
    print(f"Average routes per molecule: {successDf['numRoutes'].mean():.1f}")
    print(f"Average synthesis steps: {successDf['topRouteSteps'].mean():.1f}")
    print(f"Average confidence: {successDf['topRouteConfidence'].mean():.3f}")

    print(f"\nBest Results:")
    print(f"Highest confidence: {successDf['topRouteConfidence'].max():.3f}")
    print(f"Shortest synthesis: {successDf['topRouteSteps'].min()} steps")
    print(f"Most routes found: {successDf['numRoutes'].max()}")

# ------------------------------------------------------------------
# Display Top Molecules
# ------------------------------------------------------------------
if successful > 0:
    print("\n\nTop 5 Molecules by Confidence")

    top5 = summaryDf[summaryDf['status'] == 'Success'].nlargest(5, 'topRouteConfidence')

    for _, row in top5.iterrows():
        print(f"\n{row['moleculeId']}:")
        print(f"  SMILES: {row['smiles']}")
        print(f"  Confidence: {row['topRouteConfidence']:.3f}")
        print(f"  Steps: {row['topRouteSteps']}")
        print(f"  Total routes: {row['numRoutes']}")

    print("\n\nTop 5 Shortest Syntheses")

    shortest5 = summaryDf[summaryDf['status'] == 'Success'].nsmallest(5, 'topRouteSteps')

    for _, row in shortest5.iterrows():
        print(f"\n{row['moleculeId']}:")
        print(f"  SMILES: {row['smiles']}")
        print(f"  Steps: {row['topRouteSteps']}")
        print(f"  Confidence: {row['topRouteConfidence']:.3f}")
        print(f"  Total routes: {row['numRoutes']}")

# ------------------------------------------------------------------
# Create Visualizations
# ------------------------------------------------------------------
if hasMatplotlib and successful > 0:
    print("\n\nGenerating Visualizations")

    successDf = summaryDf[summaryDf['status'] == 'Success']

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    axes[0, 0].hist(successDf['topRouteSteps'], bins=15)
    axes[0, 0].set_xlabel('Number of Synthesis Steps')
    axes[0, 0].set_ylabel('Frequency')
    axes[0, 0].set_title('Distribution of Synthesis Route Lengths')
    axes[0, 0].grid(alpha=0.3)

    axes[0, 1].hist(successDf['topRouteConfidence'], bins=15)
    axes[0, 1].set_xlabel('Confidence Score')
    axes[0, 1].set_ylabel('Frequency')
    axes[0, 1].set_title('Distribution of Route Confidence Scores')
    axes[0, 1].grid(alpha=0.3)

    axes[1, 0].hist(
        successDf['numRoutes'],
        bins=range(1, int(successDf['numRoutes'].max()) + 2)
    )
    axes[1, 0].set_xlabel('Number of Routes Found')
    axes[1, 0].set_ylabel('Frequency')
    axes[1, 0].set_title('Distribution of Routes per Molecule')
    axes[1, 0].grid(alpha=0.3)

    axes[1, 1].scatter(
        successDf['topRouteSteps'],
        successDf['topRouteConfidence'],
        alpha=0.6,
        s=50
    )
    axes[1, 1].set_xlabel('Number of Steps')
    axes[1, 1].set_ylabel('Confidence Score')
    axes[1, 1].set_title('Route Confidence vs Synthesis Length')
    axes[1, 1].grid(alpha=0.3)

    plt.tight_layout()

    vizPath = os.path.join(rxnOutputDir, 'analysis_visualizations.png')
    plt.savefig(vizPath, dpi=300, bbox_inches='tight')
    print(f"Visualizations saved: {vizPath}")
    plt.show()

# ------------------------------------------------------------------
# Status Breakdown
# ------------------------------------------------------------------
print("\n\nStatus Breakdown")

statusCounts = summaryDf['status'].value_counts()
for status, count in statusCounts.items():
    print(f"{status}: {count} molecules")

# ------------------------------------------------------------------
# Final Summary
# ------------------------------------------------------------------
print("\n\nProcessing Complete")
print(f"All results saved to: {rxnOutputDir}")
print("\nFiles created:")
print("  retrosynthesis_summary.csv")
print("  detailed_results.json")
print("  individual_routes/")
if hasMatplotlib and successful > 0:
    print("  analysis_visualizations.png")

print("\n")

summaryDf
# Out:
# Initializing IBM RXN for Chemistry API...
# API connection successful
# Found 0 existing projects
#
# Creating / selecting project: Enamine_Antivirals_Retrosynthesis
# Using project 'Enamine_Antivirals_Retrosynthesis' with ID: None
# Project ID set successfully
#
#
# Starting Batch Retrosynthesis Analysis
# Input molecules: 20
# Max routes per molecule: 5
# Max synthesis steps: 6
# Project ID: None
#
#
# Processing 20 molecules through IBM RXN
#
#
# [1/20] molecule_0
# SMILES: COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# Failed: Exception during retrosynthesis for molecule_0: Project identifier has to be set first.
#
# [2/20] molecule_1
# SMILES: COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# Failed: Exception during retrosynthesis for molecule_1: Project identifier has to be set first.
#
# [3/20] molecule_2
# SMILES: COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# Failed: Exception during retrosynthesis for molecule_2: Project identifier has to be set first.
#
# [4/20] molecule_3
# SMILES: COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# Failed: Exception during retrosynthesis for molecule_3: Project identifier has to be set first.
#
# [5/20] molecule_4
# SMILES: COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# Failed: Exception during retrosynthesis for molecule_4: Project identifier has to be set first.
#
# [6/20] molecule_5
# SMILES: CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC
# Failed: Exception during retrosynthesis for molecule_5: Project identifier has to be set first.
#
# [7/20] molecule_6
# SMILES: CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C
# Failed: Exception during retrosynthesis for molecule_6: Project identifier has to be set first.
#
# [8/20] molecule_7
# SMILES: CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O
# Failed: Exception during retrosynthesis for molecule_7: Project identifier has to be set first.
#
# [9/20] molecule_8
# SMILES: CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C
# Failed: Exception during retrosynthesis for molecule_8: Project identifier has to be set first.
#
# [10/20] molecule_9
# SMILES: COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2
# Failed: Exception during retrosynthesis for molecule_9: Project identifier has to be set first.
#
# [11/20] molecule_10
# SMILES: CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C
# Failed: Exception during retrosynthesis for molecule_10: Project identifier has to be set first.
#
# [12/20] molecule_11
# SMILES: COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3
# Failed: Exception during retrosynthesis for molecule_11: Project identifier has to be set first.
#
# [13/20] molecule_12
# SMILES: COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC
# Failed: Exception during retrosynthesis for molecule_12: Project identifier has to be set first.
#
# [14/20] molecule_13
# SMILES: COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C
# Failed: Exception during retrosynthesis for molecule_13: Project identifier has to be set first.
#
# [15/20] molecule_14
# SMILES: COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2
# Failed: Exception during retrosynthesis for molecule_14: Project identifier has to be set first.
#
# [16/20] molecule_15
# SMILES: COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2
# Failed: Exception during retrosynthesis for molecule_15: Project identifier has to be set first.
#
# [17/20] molecule_16
# SMILES: CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C
# Failed: Exception during retrosynthesis for molecule_16: Project identifier has to be set first.
#
# [18/20] molecule_17
# SMILES: COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2
# Failed: Exception during retrosynthesis for molecule_17: Project identifier has to be set first.
#
# [19/20] molecule_18
# SMILES: COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O
# Failed: Exception during retrosynthesis for molecule_18: Project identifier has to be set first.
#
# [20/20] molecule_19
# SMILES: CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
# Failed: Exception during retrosynthesis for molecule_19: Project identifier has to be set first.
#
#
# Saving Results
# Summary saved: /mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/IBM_RXN_results/retrosynthesis_summary.csv
# Detailed results saved: /mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/IBM_RXN_results/detailed_results.json
# Individual routes saved: /mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/IBM_RXN_results/individual_routes
#
#
# Analysis Summary
# Total molecules processed: 20
# Successful: 0 (0.0%)
# No routes found: 0 (0.0%)
# Failed: 20 (100.0%)
#
# Total processing time: 0.0 minutes
# Average time per molecule: 0.0 seconds
#
#
# Status Breakdown
# Failed: 20 molecules
#
#
# Processing Complete
# All results saved to: /mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/Results/BioPKS/virus/IBM_RXN_results
#
# Files created:
#   retrosynthesis_summary.csv
#   detailed_results.json
#   individual_routes/
#     index   moleculeId                                           smiles  \
# 0       0   molecule_0   COCCN1C(=NC2=C1C(=O)NC(=O)N2C)N(C)CC=3C=CC=CC3
# 1       1   molecule_1    COCCN1C(=O)NC(=O)C(=C1N)N(CC=2C=CC=CC2)C(C)=O
# 2       2   molecule_2       COCCN1C=C(C=CC1=O)NC(=O)C2C(C=C(C)C)C2(C)C
# 3       3   molecule_3    COCCN1C(=NC2=C1C(=O)NC(=O)N2C)NN=CC=3C=CC=CC3
# 4       4   molecule_4     COC=1C=CC(OC)=C(C1)C(O)CN2C(C)=NC=3C=CC=CC32
# 5       5   molecule_5  CCC=1C=C(CC)N(N1)C2=NC3=C(C(=O)NC(=O)N3C)N2CCOC
# 6       6   molecule_6     CCOCCN1C(=NC2=C1C(=O)NC(=O)N2C)N3N=C(C)C=C3C
# 7       7   molecule_7       CC=1C=CC=C(N1)NC(=O)NC2CCCN(CC(F)(F)F)C2=O
# 8       8   molecule_8   CC1=CC=2N=CN(CC(O)CN3C(=O)NC(C)(C)C3=O)C2C=C1C
# 9       9   molecule_9      COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CC(C)OC(C)C2
# 10     10  molecule_10     CC(NC(=O)NC1=CC=CN=C1N2CCCCC2)C(=O)NC(C)(C)C
# 11     11  molecule_11        COCCN1C(=NC=2C=CC=CC21)C=3C=CC(OC)=C(O)C3
# 12     12  molecule_12    COCCN1C(=NC=2C=CC=CC21)C=3C=C(OC)C(O)=C(C3)OC
# 13     13  molecule_13                  COC=1N=CC=CC1NC(=O)NCCN2CCCCC2C
# 14     14  molecule_14               COC=1N=CC=CC1NC(=O)NCCC(=O)N2CCCC2
# 15     15  molecule_15            COC=1C=CC(=CN1)NC(=O)NCCC(=O)N2CCOCC2
# 16     16  molecule_16       CC(C)=CC1C(C(=O)NC=2C=CN(CC(N)=O)N2)C1(C)C
# 17     17  molecule_17         COCCOC=1C=CC(=CN1)NC(=O)C=2CCC(=O)N(C)N2
# 18     18  molecule_18      COCCN1C=C(C=C(C#N)C1=O)C(=O)C=2C=C(C)C=CC2O
# 19     19  molecule_19            CC(C)=CC1C(C(=O)NCCC=2C=CC=CN2)C1(C)C
#
#     status  numRoutes topRouteConfidence topRouteSteps predictionId  \
# 0   Failed          0               None          None         None
# 1   Failed          0               None          None         None
# 2   Failed          0               None          None         None
# 3   Failed          0               None          None         None
# 4   Failed          0               None          None         None
# 5   Failed          0               None          None         None
# 6   Failed          0               None          None         None
# 7   Failed          0               None          None         None
# 8   Failed          0               None          None         None
# 9   Failed          0               None          None         None
# 10  Failed          0               None          None         None
# 11  Failed          0               None          None         None
# 12  Failed          0               None          None         None
# 13  Failed          0               None          None         None
# 14  Failed          0               None          None         None
# 15  Failed          0               None          None         None
# 16  Failed          0               None          None         None
# 17  Failed          0               None          None         None
# 18  Failed          0               None          None         None
# 19  Failed          0               None          None         None
#
#     timeSeconds                                              error
# 0      0.000091  Exception during retrosynthesis for molecule_0...
# 1      0.000042  Exception during retrosynthesis for molecule_1...
# 2      0.000034  Exception during retrosynthesis for molecule_2...
# 3      0.000032  Exception during retrosynthesis for molecule_3...
# 4      0.000034  Exception during retrosynthesis for molecule_4...
# 5      0.000033  Exception during retrosynthesis for molecule_5...
# 6      0.000032  Exception during retrosynthesis for molecule_6...
# 7      0.000031  Exception during retrosynthesis for molecule_7...
# 8      0.000034  Exception during retrosynthesis for molecule_8...
# 9      0.000030  Exception during retrosynthesis for molecule_9...
# 10     0.000034  Exception during retrosynthesis for molecule_1...
# 11     0.000034  Exception during retrosynthesis for molecule_1...
# 12     0.000031  Exception during retrosynthesis for molecule_1...
# 13     0.000032  Exception during retrosynthesis for molecule_1...
# 14     0.000029  Exception during retrosynthesis for molecule_1...
# 15     0.000029  Exception during retrosynthesis for molecule_1...
# 16     0.000030  Exception during retrosynthesis for molecule_1...
# 17     0.000029  Exception during retrosynthesis for molecule_1...
# 18     0.000029  Exception during retrosynthesis for molecule_1...
# 19     0.000029  Exception during retrosynthesis for molecule_1...
