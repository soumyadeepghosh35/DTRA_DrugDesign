# %% [markdown]
# ### This notebook contain an `Immunomodulators` library
#
# Downloaded from following sources:
# - https://www.chemfaces.com/screening/screening.php?key=L20015

# %%
import os
import csv
import pandas as pd
import xlrd

# %%
dataDir = '/mnt/data.ese/nfs/users/sghosh6/DTRA_project/MACAW/DrugDesignData/'
modelBuildingDataDir = os.path.join(dataDir, 'modelBuildingData/')

# %%
Immunomodulators_Library = pd.read_excel(dataDir + '/Immunomodulators_library/Immunomodulators_Compound_Library.xls', sheet_name=0, engine="xlrd")
Immunomodulators_Library
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    20  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    40  4 4 4 4 4 4 4 4 4 4 4 4 4 3 2
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Immunomodulators_Library = pd.read_excel(dataDir + '/Immunomodulators_library/Immunomodulators_Compound_Library.xls', sheet_name=0, engine="xlrd")
#       2 Immunomodulators_Library
#
# File ~/.conda/envs/reinforcement_learning/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...
